# %%
# Alpha-Beta Pruning Example (Simple)

# Define the game tree as a dictionary
tree = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F', 'G'],
    'D': [3, 5],
    'E': [6, 9],
    'F': [1, 2],
    'G': [0, -1]
}

def alphabeta(node, depth, alpha, beta, maximizing):
    # If we reached a leaf (number), return it
    if isinstance(node, int):
        return node

    # Get children
    children = tree[node]

    if maximizing:
        value = float('-inf')
        for child in children:
            value = max(value, alphabeta(child, depth + 1, alpha, beta, False))
            alpha = max(alpha, value)
            if alpha >= beta:
                print(f"Pruned remaining children of {node} (alpha={alpha}, beta={beta})")
                break  # Beta cut-off
        return value
    else:
        value = float('inf')
        for child in children:
            value = min(value, alphabeta(child, depth + 1, alpha, beta, True))
            beta = min(beta, value)
            if beta <= alpha:
                print(f"Pruned remaining children of {node} (alpha={alpha}, beta={beta})")
                break  # Alpha cut-off
        return value


# Run the algorithm
result = alphabeta('A', 0, float('-inf'), float('inf'), True)
print("\nFinal Minimax Value at Root (A):", result)
# Out:
# Pruned remaining children of E (alpha=6, beta=5)
# Pruned remaining children of C (alpha=5, beta=2)
#
# Final Minimax Value at Root (A): 5
